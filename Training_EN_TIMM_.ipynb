# %% [markdown]
# <a href="https://colab.research.google.com/github/manvgom/Pickioset/blob/main/Training_EN_TIMM_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reset
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd drive/MyDrive/MTDI_TFM/PICKIOSET/ends_timm_v2
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# Mounted at /content/drive
# /content/drive/MyDrive/MTDI_TFM/PICKIOSET/ends_timm_v2

# %%
# !pip install torchmetrics
# Out:
# ...
#      |████████████████████████████████| 408 kB 5.1 MB/s
# ...

# %%
# !pip install pytorch_accelerated
# Out:
# ...
#      |████████████████████████████████| 52 kB 563 kB/s
# ...
#      |████████████████████████████████| 76 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 58 kB 2.8 MB/s
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
# ...

# %%
# !pip install timm
# Out:
# ...
#      |████████████████████████████████| 431 kB 5.5 MB/s
# ...

# %%
import argparse
from pathlib import Path
import timm
import timm.data
import timm.loss
import timm.optim
import timm.utils
import torch
import torchmetrics
from timm.scheduler import CosineLRScheduler
from pytorch_accelerated.callbacks import SaveBestModelCallback
from pytorch_accelerated.trainer import Trainer, DEFAULT_CALLBACKS

# %%
# %ls
# Out:
# train/  train.py  val/

# %%
# !python train.py \--data_dir=""
# Out:
# Starting training run
#
# Starting epoch 1
# 100% 8/8 [01:13<00:00,  9.14s/it]
#
# train_loss_epoch: 0.6844600081443787
# 100% 2/2 [00:15<00:00,  7.73s/it]
#
# accuracy: 0.0
#
# eval_loss_epoch: 5.4523592313130695
#
# ema_model_accuracy: 0.0
#
# Starting epoch 2
# 100% 8/8 [01:06<00:00,  8.34s/it]
#
# train_loss_epoch: 0.21001382072766622
# 100% 2/2 [00:07<00:00,  3.98s/it]
#
# accuracy: 1.0
#
# eval_loss_epoch: 0.021979527672131856
#
# ema_model_accuracy: 0.0
#
# Starting epoch 3
# 100% 8/8 [01:05<00:00,  8.22s/it]
#
# train_loss_epoch: 0.006849141915639242
# 100% 2/2 [00:08<00:00,  4.10s/it]
#
# accuracy: 1.0
#
# eval_loss_epoch: 0.005444946450491746
#
# ema_model_accuracy: 0.0
#
# Starting epoch 4
# 100% 8/8 [01:07<00:00,  8.42s/it]
#
# train_loss_epoch: 0.0011015049957980713
# 100% 2/2 [00:09<00:00,  4.95s/it]
#
# accuracy: 1.0
#
# eval_loss_epoch: 6.845595974785586e-05
#
# ema_model_accuracy: 1.0
#
# Starting epoch 5
# 100% 8/8 [01:07<00:00,  8.43s/it]
#
# ...
